# %%
import os, string, re
import glob
from pyvi import ViTokenizer, ViPosTagger

# %%
# Đặt biến các đường dẫn dữ liệu
path_train ='data/Train_Full'
path_test ='data/Test_Full'

# %%
# Các bước tiền xử lý văn bản

def normalText(sent):
    sent = str(sent).replace('_',' ').replace('/',' trên ')
    sent = re.sub('-{2,}','',sent)
    sent = re.sub('\\s+',' ', sent)
    patHagTag = r'#\s?[aăâbcdđeêghiklmnoôơpqrstuưvxyàằầbcdđèềghìklmnòồờpqrstùừvxỳáắấbcdđéếghíklmnóốớpqrstúứvxýảẳẩbcdđẻểghỉklmnỏổởpqrstủửvxỷạặậbcdđẹệghịklmnọộợpqrstụựvxỵãẵẫbcdđẽễghĩklmnõỗỡpqrstũữvxỹAĂÂBCDĐEÊGHIKLMNOÔƠPQRSTUƯVXYÀẰẦBCDĐÈỀGHÌKLMNÒỒỜPQRSTÙỪVXỲÁẮẤBCDĐÉẾGHÍKLMNÓỐỚPQRSTÚỨVXÝẠẶẬBCDĐẸỆGHỊKLMNỌỘỢPQRSTỤỰVXỴẢẲẨBCDĐẺỂGHỈKLMNỎỔỞPQRSTỦỬVXỶÃẴẪBCDĐẼỄGHĨKLMNÕỖỠPQRSTŨỮVXỸ]+'
    patURL = r"(?:http://|www.)[^\"]+"
    sent = re.sub(patURL,'website',sent)
    sent = re.sub(patHagTag,' hagtag ',sent)
    sent = re.sub('\.+','.',sent)
    sent = re.sub('(hagtag\\s+)+',' hagtag ',sent)
    sent = re.sub('\\s+',' ',sent)
    return sent

# Tách từ
def tokenizer(text):
    token = ViTokenizer.tokenize(text)
    return token

# Loại bỏ stopword trong tiếng Việt
with open("vi_stopwords.txt","r",encoding='utf8') as file:
    stopwords = file.read().split('\n')
def remove_stopword(text):
    text_new = " "
    for word in text.split(' '):
        if word.replace("_", " ").strip() not in stopwords:
            text_new +=  word +" "
    return text_new

def clean_doc(doc):
    # Tách dấu câu ra khỏi chữ trước khi tách từ
    for punc in string.punctuation:
        doc = doc.replace(punc,' '+ punc + ' ')
    # Thay thế các link web = website, hagtag ~ hagtag
    doc = normalText(doc)
    # Tách từ đối với dữ liệu
    doc = tokenizer(doc)
    # Đưa tất cả về chữ thường
    doc = doc.lower()
    # Xóa nhiều khoảng trắng thành 1 khoảng trắng
    doc = re.sub(r"\?", " \? ", doc)
    # Thay thế các giá trị số thành ký tự num
    doc = re.sub(r"[0-9]+", " num ", doc)
    # Xóa bỏ các dấu câu không cần thiết
    for punc in string.punctuation:
        if punc !="_":
            doc = doc.replace(punc,' ')
    doc = re.sub('\\s+',' ',doc)
    return doc

# %%
# Hàm đọc dữ liệu
def read_data(folder_path,threshold=1000):
    documents = []
    labels = []
    #print(os.listdir(folder_path))
    for category in os.listdir(folder_path):
        count = 0 
        print(category)
        path_new = folder_path+ "/"+category + "/*.txt"
        for filename in glob.glob(path_new):
            if count <= threshold:
                with open(filename,'r',encoding="utf-16") as file:
                    content = file.read()
                    documents.append(content)
                    labels.append(category)
                    count +=1
            else:
                break
    return documents, labels

X_train, y_train = read_data(path_train,100)
X_test, y_test = read_data(path_test,100)

print(len(X_test),len(y_test))
# Out:
# Chinh tri Xa hoi
# Doi song
# Khoa hoc
# Kinh doanh
# Phap luat
# Suc khoe
# The gioi
# The thao
# Van hoa
# Vi tinh
# Chinh tri Xa hoi
# Doi song
# Khoa hoc
# Kinh doanh
# Phap luat
# Suc khoe
# The gioi
# The thao
# Van hoa
# Vi tinh
# 1010 1010

# %%
# Hiển thị kết quả số lượng trong tập train và số lượng nhãn tương ứng
print(len(X_train),len(y_train))

# Số lượng trong tập test
print(len(X_test),len(y_test))
# Out:
# 1010 1010
# 1010 1010

# %%
# Ví dụ về hàm tiền xử lý trong văn bản
s = " Thành lập dự án POLICY phòng chống HIV/AIDS ở VN (NLĐ)- Quỹ hỗ trợ khẩn cấp về AIDS của Hoa Kỳ vừa thành lập dự án POLICY tại VN với cam kết hỗ trợ Chính phủ và nhân dân VN đối phó HIV/AIDS.Dự án có nhiệm vụ chính là cải thiện công tác phòng chống HIV/AIDS thông qua các lĩnh vực xây dựng chính sách, rà soát các văn bản pháp luật, xây dựng chiến lược quảng bá, xây dựng chương trình đào tạo về phòng chống HIV/AIDS, lên kế hoạch bố trí nguồn lực, huấn luyện và nghiên cứu về phương tiện truyền thông đại chúng, tổ chức các hoạt động nhằm giảm kỳ thị và phân biệt đối xử đối với người có HIV/AIDS... Theo TTXVN, dự án POLICY đặc biệt quan tâm đến công tác truyền thông phòng chống HIV/AIDS, coi đây là một biện pháp tích cực và hữu hiệu trong việc phòng chống có hiệu quả HIV/AIDS. Thời gian tới, dự án POLICY sẽ tiếp tục tổ chức các hoạt động nhằm nâng cao nhận thức cho những người có trách nhiệm với công tác chỉ đạo phòng chống HIV/AIDS."
print(clean_doc(s))
# Out:
# thành_lập dự_án policy phòng_chống hiv trên aids ở vn nlđ quỹ hỗ_trợ khẩn_cấp về aids của hoa_kỳ vừa thành_lập dự_án policy tại vn với cam_kết hỗ_trợ chính_phủ và nhân_dân vn đối_phó hiv trên aids dự_án có nhiệm_vụ chính là cải_thiện công_tác phòng_chống hiv trên aids thông_qua các lĩnh_vực xây_dựng chính_sách rà_soát các văn_bản pháp_luật xây_dựng chiến_lược quảng_bá xây_dựng chương_trình đào_tạo về phòng_chống hiv trên aids lên kế_hoạch bố_trí nguồn_lực huấn_luyện và nghiên_cứu về phương_tiện truyền_thông đại_chúng tổ_chức các hoạt_động nhằm giảm kỳ_thị và phân_biệt đối_xử đối_với người có hiv trên aids theo ttxvn dự_án policy đặc_biệt quan_tâm đến công_tác truyền_thông phòng_chống hiv trên aids coi đây là một biện_pháp tích_cực và hữu_hiệu trong việc phòng_chống có hiệu_quả hiv trên aids thời_gian tới dự_án policy sẽ tiếp_tục tổ_chức các hoạt_động nhằm nâng cao nhận_thức cho những người có trách_nhiệm với công_tác chỉ_đạo phòng_chống hiv trên aids

# %%
# Danh sach cac nhãn trong dữ liệu
list_label = ["Chinh tri Xa hoi","Doi song","Khoa hoc","Kinh doanh","Phap luat","Suc khoe","The gioi","The thao","Van hoa","Vi tinh"]
print("So luong nhãn: ", len(list_label))
# Out:
# So luong nhãn:  10

# %%
# Đoạn code này sẽ đọc dữ liệu trong tập train và chạy hàm tiền xử lý.
# Đối với nhãn của văn bản thì sẽ được chuyển thành dạng số với giá trị tương ứng theo index của list_label,
# Ví dụ như nhãn là "Chinh tri xa hoi" sẽ được chuyển thành 0, "Khoa hoc" là 2.
X_train_proceed = []
y_train_encoded = []
X_test_proceed = []
y_test_encoded = []
for index,data in enumerate(X_train):
    X_train_proceed.append(clean_doc(data))
    y = list_label.index(y_train[index])
    y_train_encoded.append([y])
    
for index,doc in enumerate(X_test):
    X_test_proceed.append(clean_doc(doc))
    y = list_label.index(y_test[index])
    y_test_encoded.append([y])

# %%
# Ví dụ văn bản đầu tiên và nhãn y đầu tiên trong code
print("Văn bản đầu vào: ",X_train_proceed[0])
print()
print("Nhãn bằng chữ: " + y_train[0])
print()
print("Nhãn sau khi chuyển thành số: ", y_train_encoded[0])
print()
print(len(X_train_proceed),len(y_train_proceed))
# Out:
# Văn bản đầu vào:  thành_lập dự_án policy phòng_chống hiv trên aids ở vn nlđ quỹ hỗ_trợ khẩn_cấp về aids của hoa_kỳ vừa thành_lập dự_án policy tại vn với cam_kết hỗ_trợ chính_phủ và nhân_dân vn đối_phó hiv trên aids dự_án có nhiệm_vụ chính là cải_thiện công_tác phòng_chống hiv trên aids thông_qua các lĩnh_vực xây_dựng chính_sách rà_soát các văn_bản pháp_luật xây_dựng chiến_lược quảng_bá xây_dựng chương_trình đào_tạo về phòng_chống hiv trên aids lên kế_hoạch bố_trí nguồn_lực huấn_luyện và nghiên_cứu về phương_tiện truyền_thông đại_chúng tổ_chức các hoạt_động nhằm giảm kỳ_thị và phân_biệt đối_xử đối_với người có hiv trên aids theo ttxvn dự_án policy đặc_biệt quan_tâm đến công_tác truyền_thông phòng_chống hiv trên aids coi đây là một biện_pháp tích_cực và hữu_hiệu trong việc phòng_chống có hiệu_quả hiv trên aids thời_gian tới dự_án policy sẽ tiếp_tục tổ_chức các hoạt_động nhằm nâng cao nhận_thức cho những người có trách_nhiệm với công_tác chỉ_đạo phòng_chống hiv trên aids
#
# Nhãn bằng chữ: Chinh tri Xa hoi
#
# Nhãn sau khi chuyển thành số:  [0]
#
# 1010 1010

# %%
# Biểu diễn văn bản thành vector dựa theo chỉ số TF-IDF và đưa vào mô hình Linear SVM để huấn luyện
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(analyzer='word', ngram_range=(1, 1),use_idf=True, smooth_idf=True)

X_train_tfidf = vectorizer.fit_transform(X_train_proceed)

print("Tổng số từ vựng khi đánh chỉ số TF-IDF")
print(vectorizer.get_feature_names())

print("Kích thước của vector dựa trên biểu diễn TF-IDF: ", X_train_tfidf.shape)
# Out:
# Tổng số từ vựng khi đánh chỉ số TF-IDF
# ['_hóa_thạch', '_nhập', '_pháp', '_thuận_việt', '_trận', 'a_bảng', 'a_child', 'a_còn', 'a_life', 'a_lý', 'a_ninh', 'a_pakistan', 'a_tới', 'aa', 'aap', 'aapa', 'abarca', 'abashidze', 'abayomy', 'abbas', 'abbbas', 'abc', 'abdel', 'abdel_rahman', 'abdelkrim_kaissi', 'abdul', 'abdul_qadeer', 'abdullah', 'abf', 'about', 'about_face', 'abraham', 'abramovich', 'abu', 'abu_musab_al', 'abu_shanab', 'abu_tahir', 'abu_walid', 'ac', 'ac_milan', 'acb', 'accept', 'account', 'acer', 'acetaldehit', 'acetaldehyt', 'acetaminophen', 'acetylbenzoguinoneimin', 'achievement', 'achilefu', 'acid', 'acm', 'acquitaine', 'act', 'adam_ereli', 'adam_pron', 'adaptive', 'adb', 'adcoms', 'add', 'add_point', 'addvote', 'adelaida_lenorman', 'adelaide', 'adeline', 'adeno', 'adidas', 'adl', 'adn', 'adnan_pachachi', 'adolf_hitler', 'adsl', 'advanced', 'adventure', 'adzharia', 'ae', 'aegypti', 'aeromexico', 'aerosonde', 'aerospatiale', 'aff', 'afghanistan', 'afghanistan_cuối', 'afghanitstan', 'afp', 'agadir', 'against', 'against_all', 'agassi', 'agassi_san', 'agatha_christie', 'agrarians', 'agree', 'agribank', 'ahern', 'ahmed_korei', 'ahmed_yassin', 'ai', 'ai_ai', 'ai_cập', 'ai_cập_hồi', 'ai_nấy', 'aia', 'aids', 'aime_jacquet', 'aio', 'air', 'air_france', 'airlines', 'airways', 'airways_hủy', 'airways_international', 'ait', 'ajax', 'ak', 'akhmat', 'akio', 'al', 'al_ahram', 'alabama', 'aladin', 'alain', 'alain_juppe', 'alain_juppé', 'alan', 'alan_gallet', 'alan_greenspan', 'alan_heeger', 'alanson', 'alaska', 'alaska_nối', 'alastair', 'alaves', 'alađin', 'albacete', 'albert_luque', 'albert_reynolds', 'album', 'aleksander', 'aleksandr', 'aleksandr_levenets', 'aleksandrs', 'alex', 'alex_bamberg', 'alex_bogdanovic', 'alex_corretja', 'alex_ferguson', 'alexander', 'alexander_korzhakov', 'alexander_maximov', 'alexander_rukaveshnikov', 'alexandre', 'alexei', 'alfonso_dulanto', 'alfred', 'algeria', 'algerie', 'algieria', 'ali', 'ali_al', 'ali_badaruddin', 'ali_bhutto', 'alibaba', 'alingn', 'alison_head', 'alitalia', 'alive', 'alivisators', 'alivisatos', 'alixia', 'all', 'all_enemies', 'allah', 'allen', 'alois', 'alon', 'alphaattack', 'alphachymotrypsine', 'alphattack', 'alphaworks', 'alprostadil', 'alt', 'alternative', 'alyeska', 'alzheimer', 'am', 'am_hiểu', 'amanda_johnson', 'amantadine', 'amaobi', 'amateur', 'amazon', 'ambra', 'ambroise_paré', 'ambrosini', 'ambrosio', 'amedeo_carboni', 'amelia_island', 'amelie', 'amelie_mauresmo', 'america', 'american', 'american_graffiti', 'american_virgin', 'aminosteroid', 'amiot_metayer', 'amoruso', 'amour', 'amp', 'ampe', 'amsterdam', 'amstrong', 'amsubject', 'amy', 'an', 'an_an_lão', 'an_cư', 'an_cư_lạc_nghiệp', 'an_giang', 'an_khánh', 'an_lạc', 'an_lộc_sơn', 'an_nghiệp', 'an_ninh', 'an_phận', 'an_sinh', 'an_sơn', 'an_thuyên', 'an_thần', 'an_toàn', 'an_táng', 'an_tâm', 'an_tòan', 'an_đông', 'an_ủi', 'ana', 'analog', 'anastasia_myskina', 'ancelotti', 'ancheta', 'ancic', 'ancona', 'ancona_juventus', 'and', 'anderson', 'andrade', 'andre', 'andre_agassi', 'andre_flo', 'andre_kim', 'andreev', 'andrei_pavel', 'andresen', 'andrew_gilligan', 'andrew_lee', 'andrew_tay', 'andrew_wang', 'andrew_watterson', 'andrews', 'andriy_shevchenko', 'andy', 'andy_apaid', 'andy_cole', 'andy_roddick', 'anelka', 'angel', 'angeles', 'angeles_times', 'angelos', 'angiotensine', 'angkor', 'anh', 'anh_bửu', 'anh_chàng', 'anh_chị', 'anh_dũng', 'anh_em', 'anh_giáo', 'anh_hùng', 'anh_hùng_ca', 'anh_hùng_hảo', 'anh_minh', 'anh_sĩ', 'anh_ta', 'anh_thuận', 'anh_trai', 'anh_vũ', 'anh_đào', 'anhto', 'anime', 'anna', 'anna_kournikova', 'antabuse', 'anthony', 'anthony_dupuis', 'anti', 'antonina', 'antonio', 'antonio_reyes', 'antonis', 'antonis_nikopolidis', 'antwerp', 'antôphagaxta', 'anwar_sadat', 'anđết', 'ao', 'ao_tù', 'aoife_cogan', 'aol', 'ap', 'apacs', 'apaid_jr', 'apartheid', 'apec', 'aphrodisiac', 'apocynaceae', 'apollo', 'apostol', 'appiah', 'apple', 'apply', 'aq', 'aquarius', 'arab', 'arab_news', 'arafat', 'arancha_gonzalez', 'aranda', 'arazi', 'archik', 'archite ...
# Kích thước của vector dựa trên biểu diễn TF-IDF:  (1010, 20185)

# %%
# Khởi tạo mô hình Linear SVM để huấn luyện mô hình trên tập huấn luyện
from sklearn import svm

classifier = svm.LinearSVC(multi_class="crammer_singer", C = 0.1,  penalty='l2', random_state= 42, verbose=1)
classifier.fit(X_train_tfidf, y_train_encoded)
print("Mô hình đã huấn luyện xong")
# Out:
# [LibLinear]
# LinearSVC(C=0.1, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='crammer_singer', penalty='l2', random_state=42,
#           tol=0.0001, verbose=1)

# %%
# Đoạn code này sẽ chuyển các dữ liệu trong tập test thành các vector tf-idf sau đó dùng mô hình classifier để dựa đoán
# Sau đó sử dụng các độ đo Accuracy, F1-score, Precision, Recall để đánh giá hiệu quả mô hình

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix

X_test_tfidf = vectorizer.transform(X_test_proceed)
# Dưa vector tf-idf trong tập test vào mô hình dự đoán
predicted = classifier.predict(X_test_tfidf)
y_pred = []
for y in predicted:
    y_pred.append([int(y)])
    
print("Kết quả các độ đo trong mô hình")
print("Accuracy: ",accuracy_score(y_test_encoded, y_pred))
print("F1 - score: ",f1_score(y_test_encoded, y_pred, average="macro"))
print("Precision: ",precision_score(y_test_encoded, y_pred, average="macro"))
print("Recall: ",recall_score(y_test_encoded, y_pred, average="macro"))
# Out:
# Accuracy:  0.7554455445544555
# F1 - score:  0.7403350398065884
# Precision:  0.7540117120275214
# Recall:  0.7554455445544555

# %%
# Kết quả dự đoán trên từng nhãn
print(classification_report(y_test_encoded,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92       101
#            1       0.76      0.48      0.59       101
#            2       0.78      0.43      0.55       101
#            3       0.72      0.69      0.71       101
#            4       0.78      0.89      0.83       101
#            5       0.66      0.99      0.79       101
#            6       0.58      0.44      0.50       101
#            7       0.78      0.90      0.83       101
#            8       0.81      0.90      0.85       101
#            9       0.81      0.87      0.84       101
#
#     accuracy                           0.76      1010
#    macro avg       0.75      0.76      0.74      1010
# weighted avg       0.75      0.76      0.74      1010
